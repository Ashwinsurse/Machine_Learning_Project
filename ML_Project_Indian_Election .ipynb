# %% [markdown]
# # Indian Candidates for General Election 2019

# %% [markdown]
# With over 600 Million voters voting for 8500+ candidates across 543 constituencies, the general elections in the world's largest democracy are a potential goldmine of data. While there are existing separate datasets about the votes each candidate received and the personal information of each candidate, there was no comprehensive dataset that included both these information. Thus, this dataset will provide more usability than most existing datasets in this domain.

# %% [markdown]
# DataSet Link : https://www.kaggle.com/prakrutchauhan/indian-candidates-for-general-election-2019

# %% [markdown]
# **Importing important Libraries and Loading Dataset.**
#
# Numpy:- In this Project we are using 'Numpy' Library for Numbers Operation here.
#
# Pandas:- In this Project we are using 'Pandas' Library for EDA and data related task.
#
# Matplotlib:- 'Matplotlib' we are using for Visualization Purpose.
#
# Seaborn:- With the help of 'Seaborn' we can visualize the data in advanced form.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Loding Dataset
df = pd.read_csv('Indian_Election .csv')
df
# Out:
#               STATE  ... TOTAL ELECTORS
# 0         Telangana  ...        1489790
# 1         Telangana  ...        1489790
# 2         Telangana  ...        1489790
# 3         Telangana  ...        1489790
# 4     Uttar Pradesh  ...        1937690
# ...             ...  ...            ...
# 2258    Maharashtra  ...        1916185
# 2259      Telangana  ...        1498666
# 2260      Telangana  ...        1498666
# 2261      Telangana  ...        1498666
# 2262      Telangana  ...        1498666
#
# [2263 rows x 19 columns]

# %%
#Deleting unnessasary column
del df['ASSETS']
del df['LIABILITIES']
del df['EDUCATION']
del df['CRIMINAL\nCASES']

# %%
df
# Out:
#               STATE  ... TOTAL ELECTORS
# 0         Telangana  ...        1489790
# 1         Telangana  ...        1489790
# 2         Telangana  ...        1489790
# 3         Telangana  ...        1489790
# 4     Uttar Pradesh  ...        1937690
# ...             ...  ...            ...
# 2258    Maharashtra  ...        1916185
# 2259      Telangana  ...        1498666
# 2260      Telangana  ...        1498666
# 2261      Telangana  ...        1498666
# 2262      Telangana  ...        1498666
#
# [2263 rows x 15 columns]

# %%
#Filling the Null values
df.SYMBOL.fillna(df.SYMBOL.index[0], inplace=True)
df.GENDER.fillna(df.GENDER.index[0], inplace=True)
df.AGE.fillna(df.AGE.median(), inplace=True)
df.CATEGORY.fillna(df.CATEGORY.index[0], inplace=True)

# %%
#Checking the Null values
df.isnull().sum()
# Out:
# STATE                                        0
# CONSTITUENCY                                 0
# NAME                                         0
# WINNER                                       0
# PARTY                                        0
# SYMBOL                                       0
# GENDER                                       0
# AGE                                          0
# CATEGORY                                     0
# GENERAL\nVOTES                               0
# POSTAL\nVOTES                                0
# TOTAL\nVOTES                                 0
# OVER TOTAL ELECTORS \nIN CONSTITUENCY        0
# OVER TOTAL VOTES POLLED \nIN CONSTITUENCY    0
# TOTAL ELECTORS                               0
# dtype: int64

# %%
# Visualizing dataset with the help of 'Seaborn' library.

sns.pairplot(df)

# %%
# Checking the information about data type and available columns.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2263 entries, 0 to 2262
# Data columns (total 15 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   STATE                                     2263 non-null   object
#  1   CONSTITUENCY                              2263 non-null   object
#  2   NAME                                      2263 non-null   object
#  3   WINNER                                    2263 non-null   int64
#  4   PARTY                                     2263 non-null   object
#  5   SYMBOL                                    2263 non-null   object
#  6   GENDER                                    2263 non-null   object
#  7   AGE                                       2263 non-null   float64
#  8   CATEGORY                                  2263 non-null   object
#  9   GENERAL
# VOTES                             2263 non-null   int64
#  10  POSTAL
# VOTES                              2263 non-null   int64
#  11  TOTAL
# VOTES                               2263 non-null   int64
#  12  OVER TOTAL ELECTORS
# IN CONSTITUENCY      2263 non-null   float64
#  13  OVER TOTAL VOTES POLLED
# IN CONSTITUENCY  2263 non-null   float64
#  14  TOTAL ELECTORS                            2263 non-null   int64
# dtypes: float64(3), int64(5), object(7)
# memory usage: 265.3+ KB

# %%
# Checking the Correalation between available column in dataset using heatmap (seaborn).

corr =df.corr()
sns.heatmap(corr)

# %%
#Converting categorical data into Numerical data
variable = pd.get_dummies(df.STATE, prefix='STATE')
variable1 = pd.get_dummies(df.CONSTITUENCY, prefix='CONSTITUENCY')
variable2 = pd.get_dummies(df.NAME, prefix='NAME')
variable3 = pd.get_dummies(df.PARTY, prefix='PARTY')
variable4 = pd.get_dummies(df.SYMBOL, prefix='SYMBOL')
variable5 = pd.get_dummies(df.GENDER, prefix='GENDER')
variable6 = pd.get_dummies(df.CATEGORY, prefix='CATEGORY')
New_dataset = pd.concat([variable,variable1,variable2,variable3,variable4,variable5,variable6,  df], axis='columns')

# %%
#Droping categorical column
New_dataset.drop('STATE', axis='columns', inplace=True)
New_dataset.drop('CONSTITUENCY', axis='columns', inplace=True)
New_dataset.drop('NAME', axis='columns', inplace=True)
New_dataset.drop('PARTY', axis='columns', inplace=True)
New_dataset.drop('SYMBOL', axis='columns', inplace=True)
New_dataset.drop('GENDER', axis='columns', inplace=True)
New_dataset.drop('CATEGORY', axis='columns', inplace=True)

# %%
New_dataset
# Out:
#       STATE_Andaman & Nicobar Islands  ...  TOTAL ELECTORS
# 0                                   0  ...         1489790
# 1                                   0  ...         1489790
# 2                                   0  ...         1489790
# 3                                   0  ...         1489790
# 4                                   0  ...         1937690
# ...                               ...  ...             ...
# 2258                                0  ...         1916185
# 2259                                0  ...         1498666
# 2260                                0  ...         1498666
# 2261                                0  ...         1498666
# 2262                                0  ...         1498666
#
# [2263 rows x 2864 columns]

# %%
# Seprating X fetures
X = New_dataset.iloc[:,:-1]
X
# Out:
#       STATE_Andaman & Nicobar Islands  ...  OVER TOTAL VOTES POLLED \nIN CONSTITUENCY
# 0                                   0  ...                                  35.468248
# 1                                   0  ...                                  29.964370
# 2                                   0  ...                                  29.534285
# 3                                   0  ...                                   1.225214
# 4                                   0  ...                                  56.464615
# ...                               ...  ...                                        ...
# 2258                                0  ...                                   1.250060
# 2259                                0  ...                                  41.574183
# 2260                                0  ...                                  40.977823
# 2261                                0  ...                                  13.302678
# 2262                                0  ...                                   1.066535
#
# [2263 rows x 2863 columns]

# %%
# Seprating y features
y = New_dataset.iloc[:,-1]
y
# Out:
# 0       1489790
# 1       1489790
# 2       1489790
# 3       1489790
# 4       1937690
#          ...
# 2258    1916185
# 2259    1498666
# 2260    1498666
# 2261    1498666
# 2262    1498666
# Name: TOTAL ELECTORS, Length: 2263, dtype: int64

# %%
# Importing train_test_split using Sklearn for split training and test data.
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y, test_size=0.2, random_state=0)

# %% [markdown]
# **Multiple Linear Regression**

# %%
# Importing linear regression using sklearn

from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression()

# %%
# fitting to the train data

regressor.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Predicting the data

y_pred = regressor.predict(X_test)

# %%
# Importing r2 Metrics for predciting linear regression and checking the score

from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9091465224203741

# %% [markdown]
# **DecisionTreeRegressor**

# %%
# Importing 'DecisionTreeRegressor' algorithm from sklearn library.

from sklearn.tree import DecisionTreeRegressor

# %%
# Creating Model on DecisionTree.

dtr = DecisionTreeRegressor()

# %%
# Fitting up Model on training dataset.

dtr.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
# Checking the accuracy level of Model.

dtr.score(X_test, y_test)
# Out:
# 0.8501741778653117

# %% [markdown]
# **RandomForestRegressor**

# %%
# Importing 'RandomForestRegressor' algorithm from sklearn library.

from sklearn.ensemble import RandomForestRegressor

# %%
# Creating a class and using RandomForestRegressor there..

rfr = RandomForestRegressor(n_estimators=50)

# %%
# Fitting up the Model there.

rfr.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=50, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
# Checking the accuracy level of Our Model.

rfr.score(X_test, y_test)
# Out:
# 0.8479805586842032

# %% [markdown]
# As we have use few algorithm here. So you can see the better accuracy level according to algorithm below:
# * Multiple Linear Regression :- As you have seen above in 'Multiple Linear Regression' it's providing accuracy level = 90%.
# * Decision Tree Regressor :- As you have seen above in 'Decision Tree Regressor' it's providing accuracy level = 85%.
# * Random Forest Regressor :- As you have seen above in 'Random Forest Regressor' it's providing accuracy level = 84%.
#
# Note:- So as it clearly mentioned that we are getting higher accuracy level from 'Multiple Linear Regression'. So we'll use it for our Model.
